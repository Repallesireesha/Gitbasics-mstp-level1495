# %%
## Important formulas
Lenear regrassion-y=f(n)
Y=mx+c
y=b1x+b0
root mean square error:
    RMSE=summation(X-Xmean)*(Y-Ymean)/summation(X-Xmean)^2

# %%
# polynomial---Multiple degree=ax2+bx+c
from sklearn.preprocessing import PolynomialFeatures

# %%
import numpy as np
x1=np.random.rand(100,1)
y1=0.5*x1+x1**2+np.random.rand(100,1) #y=ax2+bx+c=>a=0.5
x1
# Out:
# array([[0.66971115],
#        [0.66046703],
#        [0.76331526],
#        [0.10105395],
#        [0.41827746],
#        [0.72071828],
#        [0.62886032],
#        [0.53967526],
#        [0.93731911],
#        [0.65547764],
#        [0.94091737],
#        [0.49521804],
#        [0.91567955],
#        [0.38458039],
#        [0.93178203],
#        [0.36758085],
#        [0.25675268],
#        [0.94585609],
#        [0.47819545],
#        [0.58138219],
#        [0.570889  ],
#        [0.84652621],
#        [0.95575144],
#        [0.59352568],
#        [0.03648074],
#        [0.89139947],
#        [0.36063738],
#        [0.05414562],
#        [0.69972838],
#        [0.66271254],
#        [0.76973914],
#        [0.706841  ],
#        [0.77869199],
#        [0.64386237],
#        [0.89271021],
#        [0.94967381],
#        [0.05789808],
#        [0.00498767],
#        [0.46596615],
#        [0.25710926],
#        [0.13039307],
#        [0.63287233],
#        [0.88758681],
# ...

# %%
import numpy as np
x1=np.random.rand(100,1)
y1=0.5*x1+x1**2+np.random.rand(100,1) #y=ax2+bx+c=>a=0.5
print(x1.shape)
# Out:
# (100, 1)

# %%
print(y1.shape)
# Out:
# (100, 1)

# %%
import matplotlib.pyplot as plt
plt.plot(x1,y1,',')

# %%
plt.plot(x1,y1)

# %%
poly=PolynomialFeatures(degree=1)

# %%
import numpy as np
x1=np.random.rand(100,1)
y1=5*x1+x1**2+np.random.rand(100,1) #y=ax2+bx+c=>a=0.5
print(x1.shape)
print(y1.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
x=poly=poly.fit_transform(x1)

# %%
x
# Out:
# array([[1.00000000e+00, 2.65782825e-01],
#        [1.00000000e+00, 2.79269136e-01],
#        [1.00000000e+00, 4.11817732e-01],
#        [1.00000000e+00, 8.71289378e-04],
#        [1.00000000e+00, 7.68712375e-01],
#        [1.00000000e+00, 8.72171532e-02],
#        [1.00000000e+00, 2.28080772e-01],
#        [1.00000000e+00, 4.90556270e-02],
#        [1.00000000e+00, 7.83506377e-01],
#        [1.00000000e+00, 8.28143336e-01],
#        [1.00000000e+00, 6.14913551e-01],
#        [1.00000000e+00, 5.83394760e-01],
#        [1.00000000e+00, 8.87585643e-01],
#        [1.00000000e+00, 7.33598669e-01],
#        [1.00000000e+00, 1.77176475e-01],
#        [1.00000000e+00, 7.43864688e-02],
#        [1.00000000e+00, 3.54261756e-01],
#        [1.00000000e+00, 1.08437329e-01],
#        [1.00000000e+00, 5.71440178e-01],
#        [1.00000000e+00, 5.72422672e-01],
#        [1.00000000e+00, 2.41174557e-01],
#        [1.00000000e+00, 1.53171519e-01],
#        [1.00000000e+00, 6.05773795e-01],
# ...

# %%
x1[0]
# Out:
# array([0.26578282])

# %%
x[0]
# Out:
# array([1.        , 0.26578282])

# %%
x[3]
# Out:
# array([1.00000000e+00, 8.71289378e-04])

# %%
poly=PolynomialFeatures(degree=1)

# %%
x1[3]
# Out:
# array([0.00087129])

# %%
poly.fit(x1,y1)
# Out:
# PolynomialFeatures(degree=1, include_bias=True, interaction_only=False,
#                    order='C')

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()

# %%
lin.fit(x1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin.coef_
# Out:
# array([[5.9265159]])

# %%
lin.intercept_
# Out:
# array([0.38621854])

# %%
plt.scatter(x1,y1,c='g',label="before polynomial")
plt.plot(x1,y1,c="r",label="after polynomial linear regression")
plt.xlabel("x1")
plt.ylabel("y1")
plt.title("Linear regression with polynomial features")
plt.legend('best')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ad_df=pd.read_csv("Advertising.csv")
ad_df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
ad_df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
ad_df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
ad_df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
ad_df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
x=ad_df.iloc[:,0].values.reshape(-1,1)
print(x)
y=ad_df.iloc[:,3:].values.reshape(-1,1)
print(y)
# Out:
# [[230.1]
#  [ 44.5]
#  [ 17.2]
#  [151.5]
#  [180.8]
#  [  8.7]
#  [ 57.5]
#  [120.2]
#  [  8.6]
#  [199.8]
#  [ 66.1]
#  [214.7]
#  [ 23.8]
#  [ 97.5]
#  [204.1]
#  [195.4]
#  [ 67.8]
#  [281.4]
#  [ 69.2]
#  [147.3]
#  [218.4]
#  [237.4]
#  [ 13.2]
#  [228.3]
#  [ 62.3]
#  [262.9]
#  [142.9]
#  [240.1]
#  [248.8]
#  [ 70.6]
#  [292.9]
#  [112.9]
#  [ 97.2]
#  [265.6]
#  [ 95.7]
#  [290.7]
#  [266.9]
#  [ 74.7]
#  [ 43.1]
#  [228. ]
#  [202.5]
#  [177. ]
#  [293.6]
#  [206.9]
#  [ 25.1]
#  [175.1]
#  [ 89.7]
#  [239.9]
#  [227.2]
#  [ 66.9]
#  [199.8]
#  [100.4]
#  [216.4]
#  [182.6]
#  [262.7]
#  [198.9]
#  [  7.3]
#  [136.2]
#  [210.8]
#  [210.7]
#  [ 53.5]
#  [261.3]
#  [239.3]
#  [102.7]
#  [131.1]
#  [ 69. ]
#  [ 31.5]
#  [139.3]
#  [237.4]
#  [216.8]
#  [199.1]
#  [109.8]
#  [ 26.8]
#  [129.4]
#  [213.4]
#  [ 16.9]
#  [ 27.5]
#  [120.5]
#  [  5.4]
#  [116. ]
#  [ 76.4]
#  [239.8]
#  [ 75.3]
#  [ 68.4]
#  [213.5]
#  [193.2]
#  [ 76.3]
#  [110.7]
#  [ 88.3]
#  [109.8]
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression

# %%
lin
# Out:
# sklearn.linear_model.base.LinearRegression

# %%
x=ad_df.iloc[:,0:3].values
#print(x)
y=ad_df.iloc[:,3:].values
#y=ad_df["sales"].values
print(x.shape)
print(y.shape)
# Out:
# (200, 3)
# (200, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
lin.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predi=lin.predict(x)
y_predi
# Out:
# array([[20.52397441],
#        [12.33785482],
#        [12.30767078],
#        [17.59782951],
#        [13.18867186],
#        [12.47834763],
#        [11.72975995],
#        [12.12295317],
#        [ 3.72734086],
#        [12.55084872],
#        [ 7.0322992 ],
#        [17.28512918],
#        [10.57712073],
#        [ 8.82630048],
#        [18.43436638],
#        [20.81929952],
#        [12.82365674],
#        [23.22495716],
#        [ 9.95168206],
#        [14.16607293],
#        [18.10076728],
#        [14.7405382 ],
#        [ 6.4891503 ],
#        [16.5459329 ],
#        [ 8.14651887],
#        [15.6100386 ],
#        [14.98951429],
#        [17.05167344],
#        [19.41053803],
#        [ 9.14402389],
#        [21.6339338 ],
#        [11.3460929 ],
#        [ 7.63888314],
#        [18.86426829],
#        [ 7.57483051],
#        [17.00682618],
#        [23.40590052],
#        [15.62347779],
#        [ 9.90868103],
#        [20.44761039],
#        [16.37766467],
# ...

# %%
lin.predict([[18.8,10.8,58.4]])
# Out:
# array([[5.77479929]])

# %%
lin.predict([[15.4,31.3,65.7]])
# Out:
# array([[9.47649115]])

# %%
lin.predict([[495.5,492.7,456.9]])
# Out:
# array([[118.02997996]])

# %%
plt.scatter(ad_df["radio"].values,y,c='r',label="Before Prediction")
plt.plot(x,y_predi,c='y',label="After Prediction with Linearregression")
plt.xlabel("Cost of Tv,radio,news paper")
plt.ylabel("Sales")
plt.title("Linear regression")
plt.legend("best")
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_feat=PolynomialFeatures()

# %%
x_poly=poly_feat.fit_transform(x)
poly_feat.fit(x_poly,y)
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False,
#                    order='C')

# %% [markdown]
# ## Ridge Regression(Tikhonov regularisation)
# * Ridge and REgression are type of regulation techniques
# * Regression techniques are used to deal with overfitting and when the dataset is large
# * Ridge and Lasso Regression involes adding penalities to the regression function

# %%
# Ridge Rigression--->regularisation(alpha)

# %%
from sklearn.linear_model import Ridge

# %%
r=Ridge()

# %%
x2=5*np.random.rand(100,1)
y2=0.5*a+np.random.rand(100,1)
x2.shape
print("x2",x2)
print("y2",y2)
# Out:
# x2 [[1.14451855]
#  [2.36860174]
#  [3.0989033 ]
#  [2.86909952]
#  [1.43575605]
#  [2.36586451]
#  [1.56778484]
#  [4.69920694]
#  [3.90347183]
#  [1.00874063]
#  [3.66856283]
#  [2.39719378]
#  [0.19317037]
#  [4.24067302]
#  [3.70930709]
#  [1.60560408]
#  [3.9329103 ]
#  [2.61100548]
#  [2.8870763 ]
#  [2.59530549]
#  [2.82607066]
#  [3.24634132]
#  [2.6774057 ]
#  [4.85857531]
#  [1.30293818]
#  [1.74993886]
#  [1.75331181]
#  [1.53320662]
#  [0.65758711]
#  [4.23235231]
#  [2.40255873]
#  [0.46208013]
#  [3.90945386]
#  [4.79871652]
#  [0.418213  ]
#  [3.64648032]
#  [3.48599163]
#  [3.20700805]
#  [1.44795562]
#  [3.14113554]
#  [1.52072638]
#  [0.73783213]
#  [4.67624296]
#  [4.24768024]
#  [4.01980111]
#  [0.43922557]
#  [2.64064169]
#  [3.04156833]
#  [0.27480959]
#  [0.83719755]
#  [2.85427939]
#  [4.09424094]
#  [4.8703823 ]
#  [3.889619  ]
#  [0.02570386]
#  [0.25139858]
#  [1.2113979 ]
#  [2.61034249]
#  [2.2018969 ]
#  [4.12159995]
#  [2.34384023]
#  [2.93427114]
# ...

# %%
y2.shape
# Out:
# (100, 1)

# %%
r=Ridge(alpha=1,solver="cholesky")

# %%
r
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='cholesky', tol=0.001)

# %%
r.fit(x2,y2)
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='cholesky', tol=0.001)

# %%
r.predict([[0.89]])
# Out:
# array([[1.96116998]])

# %%
r.predict([[10.8]])
# Out:
# array([[0.59925596]])
