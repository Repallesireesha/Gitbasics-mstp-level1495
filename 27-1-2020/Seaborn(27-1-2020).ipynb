# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_orig_rc_params',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'external',
#  'factorplot',
#  'get_dataset_names',
#  'heatmap',
#  'hls_palette',
#  'husl_palette',
#  'jointplot',
#  'kdeplot',
#  'light_palette',
#  'lineplot',
#  'lmplot',
#  'load_dataset',
#  'lvplot',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(20)
y=np.random.rand(20)
plt.plot(x,y,color="m")

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(20)
y=np.random.rand(20)
plt.plot(x,y,"ko",alpha=0.1,linewidth=2,markersize=20)

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
help(sns.set)
# Out:
# Help on function set in module seaborn.rcmod:
#
# set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
#     Set aesthetic parameters in one step.
#
#     Each set of parameters can be set directly or temporarily, see the
#     referenced functions below for more information.
#
#     Parameters
#     ----------
#     context : string or dict
#         Plotting context parameters, see :func:`plotting_context`
#     style : string or dict
#         Axes style parameters, see :func:`axes_style`
#     palette : string or sequence
#         Color palette, see :func:`color_palette`
#     font : string
#         Font family, see matplotlib font manager.
#     font_scale : float, optional
#         Separate scaling factor to independently scale the size of the
#         font elements.
#     color_codes : bool
#         If ``True`` and ``palette`` is a seaborn palette, remap the shorthand
# ...

# %%
sns.set(color_codes=True)
plt.plot(x,y)

# %%
sns.set()
plt.plot(x,y)

# %%
sns.set(palette="muted")
plt.plot(x,y)

# %%
import pandas as pd
data=pd.DataFrame({'x':[2,3,4,5],'y':[4,3,88,99]})
data
# Out:
#    x   y
# 0  2   4
# 1  3   3
# 2  4  88
# 3  5  99

# %%
data['y']
# Out:
# 0     4
# 1     3
# 2    88
# 3    99
# Name: y, dtype: int64

# %%
plt.plot(data['x'],data['y'],'rs')

# %% [markdown]
# ## Relational plot

# %%
#relational plot-high level functioning plot
#scatter
#line

# %%
data
# Out:
#    x   y
# 0  2   4
# 1  3   3
# 2  4  88
# 3  5  99

# %%
help(sns.relplot)
# Out:
# Help on function relplot in module seaborn.relational:
#
# relplot(x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='brief', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)
#     Figure-level interface for drawing relational plots onto a FacetGrid.
#
#     This function provides access to several different axes-level functions
#     that show the relationship between two variables with semantic mappings
#     of subsets. The ``kind`` parameter selects the underlying axes-level
#     function to use:
#
#     - :func:`scatterplot` (with ``kind="scatter"``; the default)
#     - :func:`lineplot` (with ``kind="line"``)
#
#     Extra keyword arguments are passed to the underlying function, so you
# ...

# %%
sns.set()
sns.relplot(x='x',y='y',data=data)

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,kind="line")

# %%
sns.set()
sns.relplot(x='x',y='y',hue="y",data=data)

# %%
#loading a datasets
sns.get_dataset_names()
# Out:
# C:\Users\public\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\public\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sns.set(style="darkgrid")
t=sns.load_dataset('tips')
t.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
sns.relplot(x="total_bill",y="day",data=t)

# %%
sns.relplot(x="total_bill",y="day",data=t,hue="tip")

# %%
sns.relplot(x="total_bill",y="size",data=t,hue="tip",kind="line")

# %%
sns.set(style="darkgrid")
m=sns.load_dataset("iris")
m.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x="species",y="petal_length",data=m)

# %%
sns.relplot(x="species",y="petal_length",col="species",data=m)

# %%
m["species"].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
i["species"].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
sns.relplot(x="species",y="petal_length",col="species",data=m,hue="species")

# %%
sns.relplot(x="sepal_width",y="petal_width",data=i)

# %%
sns.relplot(x="sepal_width",y="petal_width",data=i,hue="species",col="species")

# %%
#categorial data plot
#catplot
   #SWARM PLOT
    #SCATTER PLOT
    #BAR PLOT
    #VIOLIN PLOT

# %%
sns.catplot(x="species",y="petal_length",data=i)

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=i)

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=i,kind="swarm")

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=i,kind="strip")

# %%
sns.catplot(x="species",y="petal_length",data=i,kind="violin")

# %%
sns.barplot(x="species",y="petal_length",data=i)

# %%
#box plort
f,axs=plt.subplots(1,2)
sns.boxplot(x="species",y="sepal_length",data=i,ax=axs[0])
sns.scatterplot(x="species",y="sepal_length",hue="petal_length",data=i,ax=axs[1])
plt.show()

# %%
#visualization of datasets in plots
#jointplot
#kde-kernal density
#hex
#scatter
#reg
#resid

# %%
#pair plot
sns.pairplot(data=i)

# %%
sns.pairplot(data=i,hue="species")

# %%
sns.pairplot(data=i,hue="species",palette="husl")

# %%
sns.pairplot(data=i,hue="species",markers=["o","s","d"])

# %%
sns.pairplot(i,vars=["sepal_width","sepal_length","petal_length","petal_length"])

# %%
sns.pairplot(i,vars=["sepal_width","sepal_length"])

# %%
sns.pairplot(i,diag_kind="kde")

# %%
sns.pairplot(i,diag_kind="kde",marker="+")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-dd6fa4254a28> in <module>
# ----> 1 sns.pairplot(i,diag_kind="kde",marker="+")
#
# TypeError: pairplot() got an unexpected keyword argument 'marker'

# %%
#distributed plot
x=np.random.rand(50)
sns.distplot(x)

# %%
#facetgrid plot
ff=sns.FacetGrid(i,col="species")
ff.map(plt.hist,"sepal_length")

# %%
ff=sns.FacetGrid(i,col="species")
ff.map(plt.hist,"petal_length")

# %%
#pairgrid plot 
sns.set(style="ticks")
pp=sns.PairGrid(i)
pp.map(plt.scatter)
